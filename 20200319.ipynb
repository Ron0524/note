# %% [markdown]
# <a href="https://colab.research.google.com/github/Ron0524/note/blob/master/20200319.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#作業一
import matplotlib.pyplot as plt
 
x  = [1, 2, 3, 4, 5, 6, 7, 8, 9]
y1 = [1, 3, 5, 3, 1, 3, 5, 3, 1]
y2 = [2, 4, 6, 4, 2, 4, 6, 4, 2]
plt.plot(x, y1, label="line L")
plt.plot(x, y2,'r--',label="line H") #x軸,y軸,顏色虛線,註解
plt.plot()

plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("Line Graph Example")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

boxData = [178,164,159,162,182,179,166,168,173,165]
fig = plt.figure()
plt.boxplot(boxData)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fe5fbda4fd0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fe5fbd31a20>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7fe5fbd3d4e0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7fe5fbd3d160>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fe5fbd31320>,
#   <matplotlib.lines.Line2D at 0x7fe5fbd316a0>]}

# %%
import numpy as np
import matplotlib.pyplot as plt
import mpl_toolkits.mplot3d


# 產生資料
x,y = np.mgrid[-2:2:20j, -2:2:20j]
z = 50 * np.sin(x+y)		#測試資料

#畫圖
ax = plt.subplot(111, projection='3d')	#三維圖形
ax.plot_surface(x,y,z,rstride=2, cstride=1, cmap=plt.cm.Blues_r)
ax.set_xlabel('X')			#設定坐標軸標籤
ax.set_ylabel('Y')
ax.set_zlabel('Z')


plt.show()
